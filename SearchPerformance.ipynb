# %%
import pandas as pd

data = [[1.65,	971.1],
[16.4,	1365.65],
[153.35,	797.5],
[122.8,	1029.8],
[102.25,	1016.15],
[240.2,	1389.15]
]

data_all =[[285.45,	1801.9],
[1429.1,	2984.65],
[272.55,	1309.65],
[249.1,	1297.6],
[1129.85,	2918.1],
[1135.5,	1534.8]]

data= [[971.1,1.65],
[1365.65,16.4],
[797.5,153.35],
[1029.8,122.8],
[1016.15,102.25],
[1389.15,240.2]]

data = [[0.939536,9.76027],
[1.37371,13.693],
[0.973965,24.1195],
[1.21829,13.039],
[1.20116,13.4637],
[1.21947,20.0837]]

dat1 = pd.DataFrame(data, columns=['with', 'w/o'],index=['yeast', 'human', 'word.', 'cora', 'cite.','pubmed',])

# %%
import matplotlib.pyplot as plt

import proplot as plot
import numpy as np
import pandas as pd
plot.rc['title.loc'] = 'uc'
plot.rc['axes.ymargin'] = plot.rc['axes.xmargin'] = 0.05
plot.rc.small=16
plot.rc.large=24


f, axs = plot.subplots(
    nrows=1, ncols=1, aspect=1.5, axwidth=4,
    share=0, wratios=(1)
)
# axs.format(suptitle='Error bars with various plotting commands')
# axs.format(xticklabels=['?','x','xx','yy'], xlocator=1)
# axs.format(xlocator=[0, 1, 2, 3],
#     xformatter=[r'$\alpha$', r'$\beta$', r'$\gamma$', r'$\delta$', r'$\epsilon$'],
#     title='IndexLocator',)

# axs.format(
#     xlim=(-1,6),xlocator=[0,1,2,3,4,5], xminorticks=1,
#     xformatter=['yeast', 'human', 'word.', 'cora', 'cite.', 'pub.']
# )

# xformatter=['Yeast', 'Human', 'Cora', 'Citeseer', 'Pubmed', 'Wordnet']

cycle = 'qual1'
columns=["with emb.", "w/o emb."]


# Asking add_errorbars to calculate bars
ax1 = axs[0]
obj = ax1.bar(dat1, labels=columns, legend='ul', legend_kw={'frame':False, 'ncols':1},  width=0.6)
# ax1.errorbar(x=[0,1,2,3], y=cora, xerr=0.2, yerr=10,  fmt='o')
# obj.add_errorbars()
# for bar in obj[0]:
#   bar.set_color('black')
# for bar in obj[1]:
#   bar.set_color('white')
#   bar.set_edgecolor('#6f362c')
#   bar.set_hatch("//")
ax1.format(ylabel='Time (ms)', ygrid=False, xgrid=False)

# ax2 = axs[1]
# ax2.bar(human,  cycle=cycle)
# # ax2.errorbar(x=[0,1,2,3], y=human, xerr=0.2, yerr=10,  fmt='o')
# # obj.add_errorbars()
# ax2.format(ylabel='Time (ms)', title='Human', ygrid=False)

# ax3 = axs[2]
# ax3.bar(yeast,  cycle=cycle, legend='t', labels=columns, legend_kw={'ncols': 5, 'frame': False})
# # ax3.errorbar(x=[0,1,2,3], y=yeast, xerr=0.2, yerr=10,  fmt='o')
# # obj.add_errorbars()
# ax3.format(ylabel='Time (ms)', title='Yeast', ygrid=False)


# ax4 = axs[3]
# ax4.bar(pubmed,  cycle=cycle)
# # ax4.errorbar(x=[0,1,2,3], y=pubmed, xerr=0.2, yerr=10,  fmt='o')
# # obj.add_errorbars()
# ax4.format(ylabel='Time (ms)', title='Pubmed', ygrid=False)

# # ax5 = axs[4]
# # ax5.bar(wordnet,  cycle=cycle)
# # # ax5.errorbar(x=[0,1,2,3], y=wordnet, xerr=0.2, yerr=10,  fmt='o')
# # # obj.add_errorbars()
# # ax5.format(ylabel='Time (ms)', title='Wordnet', ygrid=False)


# ax6 = axs[4]
# obj = ax6.bar(citeseer, cycle=cycle)
# # ax6.errorbar(x=[0,1,2,3], y=citeseer, xerr=0.2, yerr=10,  fmt='o')
# # obj.add_errorbars()
# ax6.format(ylabel='Time (ms)', title='Citeseer', ygrid=False)

# # f.legend(obj, columns)
plt.savefig("subgraph.eps")
