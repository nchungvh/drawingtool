# %%
# !pip3 install proplot

# %%
yeast = [[614.05,670.85,770.85],
[603.3,654.65,777.05],
[602.8,638.25,769.8],
[595.4,626.95,765.5],
[589.2,627.2,752.6],
[589.15,618.95,742.9]]

human = [[604.45,723.05,772.85],
[604.15,726.2,777.95],
[605,729.65,777.4],
[604.5,732.1,776.5],
[604.1,728.7,778.75],
[604.15,721.25,781.95]]

cora = [[676.45,632.7,736.55],
[658.05,622.15,732.1],
[658.75,617.2,730.45],
[637.8,611,731.85],
[636.9,606.55,723.3],
[632.85,603,721.75]]

pubmed = [[200.3,231.25,248],
[199.7,229.95,247.55],
[199.95,228.2,249.2],
[201.4,237.6,251.35],
[201.6,236.7,252.35],
[201.25,237.5,247.35]]

citeseer = [[688.0,484.15,445.3],
[693.0,498.05,409.3],
[692.85,482.5,402.9],
[694.1,486.1,403.1],
[693.85,493.1,403.1]]

import pandas as pd
y = pd.DataFrame(yeast, index=[10, 20, 25, 50, 75, 100], columns=['ours', 'recache', 'lru'])
h = pd.DataFrame(human, index=[10, 20, 25, 50, 75, 100], columns=['ours', 'recache', 'lru'])
co = pd.DataFrame(cora, index=[10, 20, 25, 50, 75, 100], columns=['ours', 'recache', 'lru'])
ci = pd.DataFrame(citeseer, index=[10, 20, 25, 50, 75, 100], columns=['ours', 'recache', 'lru'])
# p = pd.DataFrame(pubmed, index=[10, 20, 25, 50, 75, 100], columns=['lru', 'recache', 'ours'])
# w = pd.DataFrame(wordnet, index=["0.1", "0.2", "0.25", "0.5", "0.75", "1"], columns=['lru', 'recache', 'ours'])

# %%
yeast = [[921.9,
747.3,
548.7],
[923.65,
727.75,
522.7],
[923.2,
732.0,
510.5],
[921.95,
733.1,
510.9],
[924.0,
720.3,
499.2]]

human = [[904.3,
766.85,
583.3],
[906.05,
775.4,
582.3],
[905.35,
775.3,
582.3],
[904.9,
774.25,
582.0],
[906.15,
776.45,
582.0]]

cora = [[692.9,
389.85,
503.0],
[696.25,
439.05,
477.3],
[693.25,
411.4,
458.0],
[693.0,
415.3,
457.0],
[693.0,
411.3,
457.0]]

pubmed = [[200.3,231.25,248],
[199.7,229.95,247.55],
[199.95,228.2,249.2],
[201.4,237.6,251.35],
[201.6,236.7,252.35],
[201.25,237.5,247.35]]

citeseer = [[688.0,484.15,445.3],
[693.0,498.05,409.3],
[692.85,482.5,402.9],
[694.1,486.1,403.1],
[693.85,493.1,403.1]]

import pandas as pd
y = pd.DataFrame(yeast, index=[10, 25, 50, 75, 100], columns=['ours', 'recache', 'lru'])
h = pd.DataFrame(human, index=[10, 25, 50, 75, 100], columns=['ours', 'recache', 'lru'])
co = pd.DataFrame(cora, index=[10, 25, 50, 75, 100], columns=['ours', 'recache', 'lru'])
ci = pd.DataFrame(citeseer, index=[10, 25, 50, 75, 100], columns=['ours', 'recache', 'lru'])
# p = pd.DataFrame(pubmed, index=[10, 20, 25, 50, 75, 100], columns=['lru', 'recache', 'ours'])
# w = pd.DataFrame(wordnet, index=["0.1", "0.2", "0.25", "0.5", "0.75", "1"], columns=['lru', 'recache', 'ours'])

# %%
import matplotlib.pyplot as plt
import proplot as plot
import numpy as np
import pandas as pd
plot.rc['title.loc'] = 'uc'
plot.rc['axes.ymargin'] = plot.rc['axes.xmargin'] = 0.05
plot.rc.small=16
plot.rc.large=24

f, axs = plot.subplots(
    nrows=1, ncols=4, aspect=1.5, axwidth=4,
    share=0, wratios=(1,1,1,1)
)
# axs.format(suptitle='Error bars with various plotting commands')
# axs.format(xticklabels=['?','x','xx','yy'], xlocator=1)
# axs.format(xlocator=[0, 1, 2, 3],
#     xformatter=[r'$\alpha$', r'$\beta$', r'$\gamma$', r'$\delta$', r'$\epsilon$'],
#     title='IndexLocator',)

axs.format(
    xlim=(0,110),xlocator=[10,25,50,75,100], xlabel="Timeout (ms)", xgrid=False, ygrid=False
)

cycle = 'default'
columns=["Ours", "Recahe", "LRU"]

cycle = plot.Cycle(['k','k','k'], marker=["x","s","^"], markersize=[10,10,10], linestyle=["-","-",":"], linewidth=[1,2,2], fillstyle=['full','none','full'])


# Asking add_errorbars to calculate bars
ax1 = axs[2]
obj = ax1.plot(co.loc[[10,  25, 50, 75, 100]],  cycle=cycle)
# ax1.plot([10, 25,50, 75, 100],co['lru'][[10,  25, 50, 75, 100]], marker='x', markersize=10, fillstyle='full', linestyle='-', color='k', label='LRU')
# ax1.plot([10, 25,50, 75, 100],co['recache'][[10,  25, 50, 75, 100]], marker='s', markersize=10, fillstyle='none', lw=2, linestyle='-', color='k', label='Recache')
# ax1.plot([10, 25,50, 75, 100],co['ours'][[10,  25, 50, 75, 100]], marker='^', markersize=10, fillstyle='full', lw=2, linestyle=':', color='k', label='Ours')
# ax1.errorbar(x=[0,1,2,3], y=cora, xerr=0.2, yerr=10,  fmt='o')
# obj.add_errorbars()
ax1.format(ylabel='#cache hits')
ax1.set_title('Cora')



ax2 = axs[1]
ax2.plot(h.loc[[10,  25, 50, 75, 100]],  cycle=cycle)
# ax2.plot([10, 25,50, 75, 100],h['lru'][[10,  25, 50, 75, 100]], marker='x', markersize=10, fillstyle='full', linestyle='-', color='k', label='LRU')
# ax2.plot([10, 25,50, 75, 100],h['recache'][[10,  25, 50, 75, 100]], marker='s', markersize=10, fillstyle='none', lw=2, linestyle='-', color='k', label='Recache')
# ax2.plot([10, 25,50, 75, 100],h['ours'][[10,  25, 50, 75, 100]], marker='^', markersize=10, fillstyle='full', lw=2, linestyle=':', color='k', label='Ours')
# ax2.errorbar(x=[0,1,2,3], y=human, xerr=0.2, yerr=10,  fmt='o')
# obj.add_errorbars()
ax2.format(ylabel='#cache  hits')
ax2.set_title('Human')

ax3 = axs[0]
ax3.plot(y.loc[[10,  25, 50, 75, 100]],  cycle=cycle)
# ax3.plot([10, 25,50, 75, 100],y['lru'][[10,  25, 50, 75, 100]], marker='x', markersize=10, fillstyle='full', linestyle='-', color='k', label='LRU')
# ax3.plot([10, 25,50, 75, 100],y['recache'][[10,  25, 50, 75, 100]], marker='s', markersize=10, fillstyle='none', lw=2, linestyle='-', color='k', label='Recache')
# ax3.plot([10, 25,50, 75, 100],y['ours'][[10,  25, 50, 75, 100]], marker='^', markersize=10, fillstyle='full', lw=2, linestyle=':', color='k', label='Ours')
# ax3.errorbar(x=[0,1,2,3], y=yeast, xerr=0.2, yerr=10,  fmt='o')
# obj.add_errorbars()
ax3.format(ylabel='#cache  hits')
ax3.set_title('Yeast')

# ax4 = axs[4]
# # ax4.plot(p,  cycle=cycle)
# ax4.plot([10, 25,50, 75, 100],p['lru'][[0.1, 0.25, 0.5, 0.75, 1]], marker='x', markersize=10, fillstyle='full', linestyle='-', color='k', label='LRU')
# ax4.plot([10, 25,50, 75, 100],p['recache'][[0.1, 0.25, 0.5, 0.75, 1]], marker='s', markersize=10, fillstyle='none', lw=2, linestyle='-', color='k', label='Recache')
# ax4.plot([10, 25,50, 75, 100],p['ours'][[0.1, 0.25, 0.5, 0.75, 1]], marker='^', markersize=10, fillstyle='full', lw=2, linestyle=':', color='k', label='Ours')
# # ax4.errorbar(x=[0,1,2,3], y=pubmed, xerr=0.2, yerr=10,  fmt='o')
# # obj.add_errorbars()
# ax4.format(ylabel='Number of hits')
# ax4.set_title('Pubmed')

# ax5 = axs[3]
# ax5.bar(wordnet,  cycle=cycle)
# # ax5.errorbar(x=[0,1,2,3], y=wordnet, xerr=0.2, yerr=10,  fmt='o')
# # obj.add_errorbars()
# ax5.format(ylabel='Time (ms)', title='Wordnet', ygrid=False, xgrid=False)
# ax.legend(labels=columns, legend_kw={'ncols': 5, 'frame': False})

ax6 = axs[3]
obj = ax6.plot(ci.loc[[10,  25, 50, 75, 100]], cycle=cycle,legend='r', labels=columns, legend_kw={'frameon':False, 'ncols':1})
# a = ax6.plot([10, 25,50, 75, 100],ci['lru'][[0.1, 0.25, 0.5, 0.75, 1]], marker='x', markersize=10, fillstyle='full', linestyle='-', color='k', label='LRU')
# b = ax6.plot([10, 25,50, 75, 100],ci['recache'][[0.1, 0.25, 0.5, 0.75, 1]], marker='s', markersize=10, fillstyle='none', lw=2, linestyle='-', color='k', label='Recache')
# c = ax6.plot([10, 25,50, 75, 100],ci['ours'][[0.1, 0.25, 0.5, 0.75, 1]], marker='^', markersize=10, fillstyle='full', lw=2, linestyle=':', color='k', label='Ours')
# ax6.errorbar(x=[0,1,2,3], y=citeseer, xerr=0.2, yerr=10,  fmt='o')
# obj.add_errorbars()
ax6.format(ylabel='#cache hits')
ax6.set_title('Citeseer')
# ax6.legend(loc='ul')

# f.legend(obj, columns)
plt.savefig("cache_add.eps")
plt.show()

# %%
yeast = [[880.1,
881.05,
883.5,
882.6,
882.0],
[823.45,
815.6,
812.4,
811.7,
810.9],
[794.4,
794.0,
793.3,
794.5,
795.0]]

human = [[890.95,
889.25,
888.7,
889.55,
890.2],
[851.05,
846.0,
844.45,
845.95,
845.9],
[808.0,
807.4,
807.2,
807.1,
807.1]]

cora = [[714.3,
715.8,
711.55,
711.8,
711.35],
[546.4,
544.65,
535.15,
535.9,
533.5],
[636.55,
636.3,
637.9,
637.9,
637.1]]

# pubmed = [[200.3,231.25,248],
# [199.7,229.95,247.55],
# [199.95,228.2,249.2],
# [201.4,237.6,251.35],
# [201.6,236.7,252.35],
# [201.25,237.5,247.35]]

citeseer = [[692.7,
693.65,
695.65,
694.5,
694.4],
[622.5,
616.0,
614.4,
614.0,
612.2],
[654.8,
655.2,
654.5,
654.5,
654.5]]

import pandas as pd
y = pd.DataFrame(yeast, columns=[10, 25, 50, 75, 100], index=['ours', 'recache', 'lru']).T
h = pd.DataFrame(human, columns=[10, 25, 50, 75, 100], index=['ours', 'recache', 'lru']).T
co = pd.DataFrame(cora, columns=[10, 25, 50, 75, 100], index=['ours', 'recache', 'lru']).T
ci = pd.DataFrame(citeseer, columns=[10, 25, 50, 75, 100], index=['ours', 'recache', 'lru']).T
# p = pd.DataFrame(pubmed, index=[10, 20, 25, 50, 75, 100], columns=['lru', 'recache', 'ours'])
# w = pd.DataFrame(wordnet, index=["0.1", "0.2", "0.25", "0.5", "0.75", "1"], columns=['lru', 'recache', 'ours'])

# %%
import matplotlib.pyplot as plt
import proplot as plot
import numpy as np
import pandas as pd
plot.rc['title.loc'] = 'uc'
plot.rc['axes.ymargin'] = plot.rc['axes.xmargin'] = 0.05
plot.rc.small=16
plot.rc.large=22

f, axs = plot.subplots(
    nrows=2, ncols=2, aspect=1.5, journal='nat2',
    share=1, hspace=0.35
)

# f, axs = plot.subplots(
#     nrows=1, ncols=4, aspect=1.5, journal='nat2',
#     share=1, hspace=0.45
# )
# axs.format(suptitle='Error bars with various plotting commands')
# axs.format(xticklabels=['?','x','xx','yy'], xlocator=1)
# axs.format(xlocator=[0, 1, 2, 3],
#     xformatter=[r'$\alpha$', r'$\beta$', r'$\gamma$', r'$\delta$', r'$\epsilon$'],
#     title='IndexLocator',)

axs.format(
    xlim=(0,110),xlocator=[10,25,50,75,100], xlabel="Timeout (ms)", xgrid=False, ygrid=False
)

cycle = 'default'
columns=["Ours", "Recahe", "LRU"]

cycle = plot.Cycle(['k','k','k'], marker=["x","s","^"], markersize=[10,10,10], linestyle=["-","-",":"], linewidth=[1,2,2], fillstyle=['full','none','full'])


# Asking add_errorbars to calculate bars
ax1 = axs[2]
obj = ax1.plot(co.loc[[10,  25, 50, 75, 100]],  cycle=cycle)
# ax1.plot([10, 25,50, 75, 100],co['lru'][[10,  25, 50, 75, 100]], marker='x', markersize=10, fillstyle='full', linestyle='-', color='k', label='LRU')
# ax1.plot([10, 25,50, 75, 100],co['recache'][[10,  25, 50, 75, 100]], marker='s', markersize=10, fillstyle='none', lw=2, linestyle='-', color='k', label='Recache')
# ax1.plot([10, 25,50, 75, 100],co['ours'][[10,  25, 50, 75, 100]], marker='^', markersize=10, fillstyle='full', lw=2, linestyle=':', color='k', label='Ours')
# ax1.errorbar(x=[0,1,2,3], y=cora, xerr=0.2, yerr=10,  fmt='o')
# obj.add_errorbars()
ax1.format(ylabel='#cache hits',ylocator=50, ylim=(500,800))
ax1.set_title('Cora', x=0.5,y=0.79)



ax2 = axs[1]
ax2.plot(h.loc[[10,  25, 50, 75, 100]],  cycle=cycle)
# ax2.plot([10, 25,50, 75, 100],h['lru'][[10,  25, 50, 75, 100]], marker='x', markersize=10, fillstyle='full', linestyle='-', color='k', label='LRU')
# ax2.plot([10, 25,50, 75, 100],h['recache'][[10,  25, 50, 75, 100]], marker='s', markersize=10, fillstyle='none', lw=2, linestyle='-', color='k', label='Recache')
# ax2.plot([10, 25,50, 75, 100],h['ours'][[10,  25, 50, 75, 100]], marker='^', markersize=10, fillstyle='full', lw=2, linestyle=':', color='k', label='Ours')
# ax2.errorbar(x=[0,1,2,3], y=human, xerr=0.2, yerr=10,  fmt='o')
# obj.add_errorbars()
ax2.format(ylabel='#cache  hits',ylocator=25, ylim=(800,925))
ax2.set_title('Human', x=0.5,y=0.79)

ax3 = axs[0]
ax3.plot(y.loc[[10,  25, 50, 75, 100]],  cycle=cycle)
# ax3.plot([10, 25,50, 75, 100],y['lru'][[10,  25, 50, 75, 100]], marker='x', markersize=10, fillstyle='full', linestyle='-', color='k', label='LRU')
# ax3.plot([10, 25,50, 75, 100],y['recache'][[10,  25, 50, 75, 100]], marker='s', markersize=10, fillstyle='none', lw=2, linestyle='-', color='k', label='Recache')
# ax3.plot([10, 25,50, 75, 100],y['ours'][[10,  25, 50, 75, 100]], marker='^', markersize=10, fillstyle='full', lw=2, linestyle=':', color='k', label='Ours')
# ax3.errorbar(x=[0,1,2,3], y=yeast, xerr=0.2, yerr=10,  fmt='o')
# obj.add_errorbars()
ax3.format(ylabel='#cache  hits',ylocator=25, ylim=(775,925))
ax3.set_title('Yeast', x=0.5,y=0.79)

# ax4 = axs[4]
# # ax4.plot(p,  cycle=cycle)
# ax4.plot([10, 25,50, 75, 100],p['lru'][[0.1, 0.25, 0.5, 0.75, 1]], marker='x', markersize=10, fillstyle='full', linestyle='-', color='k', label='LRU')
# ax4.plot([10, 25,50, 75, 100],p['recache'][[0.1, 0.25, 0.5, 0.75, 1]], marker='s', markersize=10, fillstyle='none', lw=2, linestyle='-', color='k', label='Recache')
# ax4.plot([10, 25,50, 75, 100],p['ours'][[0.1, 0.25, 0.5, 0.75, 1]], marker='^', markersize=10, fillstyle='full', lw=2, linestyle=':', color='k', label='Ours')
# # ax4.errorbar(x=[0,1,2,3], y=pubmed, xerr=0.2, yerr=10,  fmt='o')
# # obj.add_errorbars()
# ax4.format(ylabel='Number of hits')
# ax4.set_title('Pubmed')

# ax5 = axs[3]
# ax5.bar(wordnet,  cycle=cycle)
# # ax5.errorbar(x=[0,1,2,3], y=wordnet, xerr=0.2, yerr=10,  fmt='o')
# # obj.add_errorbars()
# ax5.format(ylabel='Time (ms)', title='Wordnet', ygrid=False, xgrid=False)
# ax.legend(labels=columns, legend_kw={'ncols': 5, 'frame': False})

ax6 = axs[3]
# obj = ax6.plot(ci.loc[[10,  25, 50, 75, 100]], cycle=cycle,legend='r', labels=columns, legend_kw={'frameon':False, 'ncols':1})
obj = ax6.plot(ci.loc[[10,  25, 50, 75, 100]], cycle=cycle)
# a = ax6.plot([10, 25,50, 75, 100],ci['lru'][[0.1, 0.25, 0.5, 0.75, 1]], marker='x', markersize=10, fillstyle='full', linestyle='-', color='k', label='LRU')
# b = ax6.plot([10, 25,50, 75, 100],ci['recache'][[0.1, 0.25, 0.5, 0.75, 1]], marker='s', markersize=10, fillstyle='none', lw=2, linestyle='-', color='k', label='Recache')
# c = ax6.plot([10, 25,50, 75, 100],ci['ours'][[0.1, 0.25, 0.5, 0.75, 1]], marker='^', markersize=10, fillstyle='full', lw=2, linestyle=':', color='k', label='Ours')
# ax6.errorbar(x=[0,1,2,3], y=citeseer, xerr=0.2, yerr=10,  fmt='o')
# obj.add_errorbars()
ax6.format(ylabel='#cache hits',ylocator=25, ylim=(600,745))
ax6.set_title('Citeseer', x=0.5,y=0.79)
# ax6.legend(loc='ul')
# ax3.legend(obj,labels=columns,frameon=False,  ncol=3,bbox_to_anchor=(0.5, 0.5))
f.legend(obj,labels=columns, ncols=3, frame=False, loc='t',space=0.2, fontsize=20)


# f.legend(obj, columns)
plt.savefig("cache_add.eps")
plt.show()

# %%
obj
# Out:
# (<matplotlib.lines.Line2D at 0x2bcb8643e88>,
# ...
#  <matplotlib.lines.Line2D at 0x2bcb8867ec8>)

# %%
type(f)
# Out:
# proplot.subplots.Figure

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams.update({'font.size': 30})
# matplotlib.rcParams['text.usetex'] = True
ax = plt.subplot(2,1,1)


ax.plot([10, 25,50, 75, 100],y['lru'][[0.1, 0.25, 0.5, 0.75, 1]], marker='x', markersize=10, fillstyle='full', linestyle='-', color='k', label='LRU')
ax.plot([10, 25,50, 75, 100],y['recache'][[0.1, 0.25, 0.5, 0.75, 1]], marker='s', markersize=10, fillstyle='none', lw=2, linestyle='-', color='k', label='Recache')
ax.plot([10, 25,50, 75, 100],y['ours'][[0.1, 0.25, 0.5, 0.75, 1]], marker='^', markersize=10, fillstyle='full', lw=2, linestyle=':', color='k', label='Ours')


plt.xlabel('Timeout (ms)')
# ylabel('\#Users') #'Users who tweet/retweet rumors'
# plt.title('Avg. running time (ms)', loc='left', color='black', fontsize=28)
plt.grid(True,alpha=0.5)
ax.set_xticks([10,20, 25,50, 75, 100])
plt.ylim()


#legend
# ax.legend(fontsize=20, loc='upper left', frameon=False, ncol=3, labelspacing=0, 
#           columnspacing=0.3, borderpad = 0.3, handletextpad=0.3)

#Save file
# dir = "./"
# plt.savefig(dir + "Fig1.png", bbox_inches='tight', dpi=300)

# %%
a
