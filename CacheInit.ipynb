# %%
data = [[0,6.1,13.932,19.732,26.143,32.044,38.3555,44.9845,51.2025,57.965,64.289],
[0,11.1775,22.1825,31.4635,40.254,49.3455,58.435,67.9315,77.0915,86.227,94.946]]

data = [[0,149.987692,386.9647638,539.5553194,781.0131285,952.078476],
[0,138.0391937,276.3723647,430.4806709,612.3812271,777.2838666]]


data = [[0,476.560238,878.0110341,1239.59485,1632.12489,2146.654184],
[0,387.4490764,669.3421774,989.6662627,1318.297376,1795.122263]]

import pandas as pd
dat = pd.DataFrame(data, index=['with', 'w/o'], columns=[0,10,20,30,40,50]).T

# %%
import matplotlib.pyplot as plt
import proplot as plot
import numpy as np
import pandas as pd
plot.rc['title.loc'] = 'uc'
plot.rc['axes.ymargin'] = plot.rc['axes.xmargin'] = 0.05
plot.rc.small=15
plot.rc.large=24

f, axs = plot.subplots(
    nrows=1, ncols=1, axwidth=3, axheight=3,
    share=0, wratios=(1)
)
axs.format(
#     xlim=(-10,110), xlabel="Query sequence", xgrid=False, ygrid=False
    xlim=(-10,60), xlabel="Query sequence", xgrid=False, ygrid=False
)

cycle = 'default'
columns=["W/o init.", "With init."]

cycle = plot.Cycle(['k','k','k'], marker=[".","s","^"], markersize=[10,10,10], linestyle=["-","-",":"], linewidth=[1,2,2], fillstyle=['full','none','full'])

ax6 = axs[0]
obj = ax6.plot(dat, cycle=cycle,legend='ul', labels=columns, legend_kw={'frameon':False, 'ncols':1})
ax6.format(ylabel='Cummulative answer. time (s)')
# ax6.set_title('Wordnet')
# ax6.legend(loc='ul')

# f.legend(obj, columns)
plt.savefig("cache_cold.eps")
plt.show()
